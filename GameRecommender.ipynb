# %% [markdown]
# <a href="https://colab.research.google.com/github/rectangle-man/GameRecommendationSystem/blob/main/GameRecommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #LOADING LIBRARIES

# %%
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler
from datetime import datetime

# %% [markdown]
# #READING DATASET

# %%
df = pd.read_csv('all_games.csv')
df['name']=df['name']. apply(str.upper)
df['release_date']= pd.to_datetime(df['release_date'])
df['release_date']= pd.to_datetime(df['release_date'])
df['release_date'] = df['release_date'].astype(int) / 10**9
df['user_review'].replace({'tbd': '-1'}, inplace=True)
df = df.drop_duplicates(subset='name')
df
# Out:
#        index                                        name        platform  \
# 0          0        THE LEGEND OF ZELDA: OCARINA OF TIME     Nintendo 64
# 1          1                    TONY HAWK'S PRO SKATER 2     PlayStation
# 2          2                         GRAND THEFT AUTO IV   PlayStation 3
# 3          3                                 SOULCALIBUR       Dreamcast
# 5          5                          SUPER MARIO GALAXY             Wii
# ...      ...                                         ...             ...
# 18793  18793                            CHARLIE'S ANGELS        GameCube
# 18795  18795                    FAST & FURIOUS: SHOWDOWN        Xbox 360
# 18796  18796                     DRAKE OF THE 99 DRAGONS            Xbox
# 18797  18797  AFRO SAMURAI 2: REVENGE OF KUMA VOLUME ONE   PlayStation 4
# 18798  18798   INFESTATION: SURVIVOR STORIES (THE WAR Z)              PC
#
#        release_date                                            summary  \
# 0      9.117792e+08  As a young boy, Link is tricked by Ganondorf, ...
# 1      9.694080e+08  As most major publishers' development efforts ...
# 2      1.209427e+09  [Metacritic's 2008 PS3 Game of the Year; Also ...
# 3      9.367488e+08  This is a tale of souls and swords, transcendi...
# 5      1.194826e+09  [Metacritic's 2007 Wii Game of the Year] The u...
# ...             ...                                                ...
# 18793  1.057709e+09  Join Natalie, Dylan, and Alex for an intense a...
# 18795  1.369094e+09  Fast & Furious: Showdown takes some of the fra...
# 18796  1.067818e+09  Drake is out for revenge in a supernatural Hon...
# 18797  1.442880e+09  Head out on a journey of redemption, driven by...
# 18798  1.350259e+09  (Formerly known as "The War Z") It has been 5 ...
#
#        meta_score user_review
# 0              99         9.1
# 1              98         7.4
# 2              98         7.7
# 3              98         8.4
# 5              97         9.1
# ...           ...         ...
# 18793          23         4.3
# 18795          22         1.3
# 18796          22         1.7
# 18797          21         2.9
# 18798          20         1.7
#
# [12227 rows x 7 columns]

# %% [markdown]
# #MODEL PREREQUISITES

# %%
#Important features for the model
features = df[['name', 'user_review', 'meta_score','release_date']]

#User input
favorite_titles = ['NIER: AUTOMATA', 'SUPER MARIO GALAXY', 'NFESTATION: SURVIVOR STORIES (THE WAR Z)','SOULCALIBUR']

# %% [markdown]
# #COLLABORATIVE FILTERING

# %% [markdown]
# **FILTERING DATA FOR USER INPUTS**

# %%
user_data = features[features['name'].isin(favorite_titles)]
user_data
# Out:
#                    name  user_review  meta_score  release_date
# 3           SOULCALIBUR     0.878505    0.987342      0.164718
# 5    SUPER MARIO GALAXY     0.943925    0.974684      0.473771
# 793      NIER: AUTOMATA     0.925234    0.860759      0.825867

# %% [markdown]
# **COLLABORATIVE FILTERING MODEL**

# %%
scaler = MinMaxScaler()
df[['user_review', 'meta_score','release_date']] = scaler.fit_transform(df[['user_review', 'meta_score','release_date']])

# Calculate cosine similarity
similarity_matrix = cosine_similarity(user_data[['user_review', 'meta_score', 'release_date']],
                                      df[['user_review', 'meta_score', 'release_date']])

# Find games similar to the user's favorites
similar_games = pd.DataFrame(similarity_matrix, index=user_data['name'], columns=df['name'])
similar_games
# Out:
# name                THE LEGEND OF ZELDA: OCARINA OF TIME  \
# name
# SOULCALIBUR                                     0.999227
# SUPER MARIO GALAXY                              0.971684
# NIER: AUTOMATA                                  0.884721
#
# name                TONY HAWK'S PRO SKATER 2  GRAND THEFT AUTO IV  \
# name
# SOULCALIBUR                         0.997843             0.970013
# SUPER MARIO GALAXY                  0.980161             0.996676
# NIER: AUTOMATA                      0.904394             0.970726
#
# name                SOULCALIBUR  SUPER MARIO GALAXY  SUPER MARIO GALAXY 2  \
# name
# SOULCALIBUR            1.000000            0.976789              0.962081
# SUPER MARIO GALAXY     0.976789            1.000000              0.998121
# NIER: AUTOMATA         0.894631            0.969569              0.982508
#
# name                RED DEAD REDEMPTION 2  GRAND THEFT AUTO V  \
# name
# SOULCALIBUR                      0.887051            0.921222
# SUPER MARIO GALAXY               0.963093            0.980916
# NIER: AUTOMATA                   0.995564            0.993655
#
# name                DISCO ELYSIUM: THE FINAL CUT  \
# name
# SOULCALIBUR                             0.868073
# SUPER MARIO GALAXY                      0.952440
# NIER: AUTOMATA                          0.995002
#
# name                THE LEGEND OF ZELDA: BREATH OF THE WILD  ...  \
# name                                                         ...
# SOULCALIBUR                                        0.908305  ...
# SUPER MARIO GALAXY                                 0.975919  ...
# NIER: AUTOMATA                                     0.997860  ...
#
# name                GAME PARTY CHAMPIONS  PULSE RACER  FIGHTER WITHIN  \
# name
# SOULCALIBUR                     0.489971     0.644915        0.443640
# SUPER MARIO GALAXY              0.661283     0.777650        0.622858
# NIER: AUTOMATA                  0.818598     0.883603        0.791559
#
# name                FLATOUT 3: CHAOS & DESTRUCTION  HOMIE ROLLERZ  \
# name
# SOULCALIBUR                               0.481492       0.545292
# SUPER MARIO GALAXY                        0.653532       0.702558
# NIER: AUTOMATA                            0.812073       0.841077
#
# name                CHARLIE'S ANGELS  FAST & FURIOUS: SHOWDOWN  \
# name
# SOULCALIBUR                 0.671694                  0.342146
# SUPER MARIO GALAXY          0.774135                  0.535402
# NIER: AUTOMATA              0.844949                  0.725632
#
# name                DRAKE OF THE 99 DRAGONS  \
# name
# SOULCALIBUR                        0.549289
# SUPER MARIO GALAXY                 0.705394
# NIER: AUTOMATA                     0.842396
#
# name                AFRO SAMURAI 2: REVENGE OF KUMA VOLUME ONE  \
# name
# SOULCALIBUR                                           0.404743
# SUPER MARIO GALAXY                                    0.588783
# NIER: AUTOMATA                                        0.764930
#
# name                INFESTATION: SURVIVOR STORIES (THE WAR Z)
# name
# SOULCALIBUR                                          0.351114
# SUPER MARIO GALAXY                                   0.542493
# NIER: AUTOMATA                                       0.729876
#
# [3 rows x 12227 columns]

# %% [markdown]
# #RECOMMENDER

# %%
# Get games not in the user's favorites
features = features.drop_duplicates(subset=['name'])
not_favorites = features[~features['name'].isin(favorite_titles)]

# Calculate average similarity scores for each non-favorite game
not_favorites['avg_similarity'] = not_favorites['name'].apply(lambda x: similar_games[x].mean())
not_favorites
# Out:
# <ipython-input-113-c2e6d50468fb>:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   not_favorites['avg_similarity'] = not_favorites['name'].apply(lambda x: similar_games[x].mean())
#                                              name  user_review  meta_score  \
# 0            THE LEGEND OF ZELDA: OCARINA OF TIME     0.943925    1.000000
# 1                        TONY HAWK'S PRO SKATER 2     0.785047    0.987342
# 2                             GRAND THEFT AUTO IV     0.813084    0.987342
# 6                            SUPER MARIO GALAXY 2     0.943925    0.974684
# 7                           RED DEAD REDEMPTION 2     0.841121    0.974684
# ...                                           ...          ...         ...
# 18793                            CHARLIE'S ANGELS     0.495327    0.037975
# 18795                    FAST & FURIOUS: SHOWDOWN     0.214953    0.025316
# 18796                     DRAKE OF THE 99 DRAGONS     0.252336    0.025316
# 18797  AFRO SAMURAI 2: REVENGE OF KUMA VOLUME ONE     0.364486    0.012658
# 18798   INFESTATION: SURVIVOR STORIES (THE WAR Z)     0.252336    0.000000
#
#        release_date  avg_similarity
# 0          0.134816        0.951877
# 1          0.203828        0.960800
# 2          0.491257        0.979138
# 6          0.569271        0.980904
# 7          0.887739        0.948570
# ...             ...             ...
# 18793      0.309571        0.763593
# 18795      0.682462        0.534393
# 18796      0.321676        0.699026
# 18797      0.770823        0.586152
# 18798      0.659907        0.541161
#
# [12224 rows x 5 columns]

# %% [markdown]
# **OUTPUT**

# %%
# Sort games by average similarity
recommended_games = not_favorites.sort_values(by='avg_similarity', ascending=False)['name'].head(5).tolist()
print(recommended_games)
# Out:
# ['NFL STREET 2', 'STAR WARS GALAXIES: JUMP TO LIGHTSPEED', 'FORZA MOTORSPORT 2', 'GALACTIC CIVILIZATIONS II: DREAD LORDS', 'THE ORANGE BOX']
